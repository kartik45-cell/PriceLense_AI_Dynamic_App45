# %% [markdown]
# # 02 — Exploratory data analysis
#
# Revenue, discount and promotion patterns. Use this story in the presentation before showing the model.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
from src.data_processing import load_raw_data, clean_transactions
raw, meals = load_raw_data(ROOT / 'data')
df = clean_transactions(raw, meals)
print(df.shape, df.week.min(), df.week.max())

weekly = df.groupby('week', as_index=False).agg(orders=('num_orders','sum'), revenue=('revenue','sum'), avg_price=('checkout_price','mean'))
weekly.tail()
