# %% [markdown]
# # 06 — Revenue optimization
#
# Test price scenarios within a ±20% guardrail and require a modeled demand loss of no more than 15%.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
from src.data_processing import load_raw_data, clean_transactions
raw, meals = load_raw_data(ROOT / 'data')
df = clean_transactions(raw, meals)
print(df.shape, df.week.min(), df.week.max())

from src.feature_engineering import make_model_frame
from src.demand_model import train_demand_model
from src.optimizer import optimize_price
frame = make_model_frame(df); model = train_demand_model(frame)
latest = frame.sort_values('week').iloc[-1]
simulation = optimize_price(model, latest)
simulation[['checkout_price','predicted_demand','expected_revenue','demand_loss_vs_current','is_recommended']]
