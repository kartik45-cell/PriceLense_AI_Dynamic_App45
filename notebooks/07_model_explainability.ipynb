# %% [markdown]
# # 07 — Explainability and rollout guardrails
#
# Explain each recommendation with price, demand, revenue, historical elasticity, and confidence checks. Do not present observational elasticity as causal proof.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
from src.data_processing import load_raw_data, clean_transactions
raw, meals = load_raw_data(ROOT / 'data')
df = clean_transactions(raw, meals)
print(df.shape, df.week.min(), df.week.max())

from src.elasticity import estimate_elasticity
print('Operational guardrails: price change <= 20%, predicted demand loss <= 15%, human approval required.')
estimate_elasticity(df).groupby('elasticity_band').size()
